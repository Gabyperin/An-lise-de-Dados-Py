# %%
# !pip install yfinance
# !pip install selenium 
# !pip install webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ## Coletando os Dados - Cotação de ações e ETFs

# %%
import yfinance as yf

# %%
# Banco do Bradesco e Itau 
lista_empresas = ["BBDC4.SA", "ITUB4.SA"]

dados_empresas = yf.download(lista_empresas)
dados_empresas
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Price      Adj Close               Close                High             \
# Ticker      BBDC4.SA   ITUB4.SA BBDC4.SA   ITUB4.SA BBDC4.SA   ITUB4.SA
# Date
# 2000-12-21       NaN   1.644482      NaN   2.960552      NaN   2.988535
# 2000-12-22       NaN   1.573203      NaN   2.832229      NaN   2.930748
# 2000-12-25       NaN   1.573203      NaN   2.832229      NaN   2.832229
# 2000-12-26       NaN   1.572744      NaN   2.831401      NaN   2.834712
# 2000-12-27       NaN   1.626087      NaN   2.927437      NaN   2.927437
# ...              ...        ...      ...        ...      ...        ...
# 2024-04-11     14.39  32.799999    14.39  32.799999    14.44  32.930000
# 2024-04-12     14.21  32.459999    14.21  32.459999    14.37  32.730000
# 2024-04-15     14.00  31.910000    14.00  31.910000    14.29  32.630001
# 2024-04-16     13.90  31.670000    13.90  31.670000    14.02  31.870001
# ...

# %%
# !pip install webdriver-manager
# !pip install selenium webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# %%
url_site = "https://www.fundamentus.com.br/resultado.php"
driver.get(url_site)

# %%
local_tabela = "/html/body/div[1]/div[2]/table"

elemento = driver.find_element("xpath", local_tabela)
html_tabela = elemento.get_attribute("outerHTML")
html_tabela
# Out:
# '<table id="resultado" class="resultado rowstyle-par colstyle-col no-arrow" border="0" cellpadding="0" cellspacing="0">\n<thead>\n<tr>\n<th style="-moz-user-select: none;" class="fd-column-0 sortable-text "><a href="#" class="fdTableSortTrigger" title="Sort on “Papel”">Papel</a></th>\n<th style="-moz-user-select: none;" class="sortable-numeric fd-column-1"><a href="#" class="fdTableSortTrigger" title="Sort on “Cotação”">Cotação</a></th>\n<th style="-moz-user-select: none;" class="sortable-numeric fd-column-2"><a href="#" class="fdTableSortTrigger" title="Sort on “P/L”">P/L</a></th>\n<th style="-moz-user-select: none;" class="sortable-numeric fd-column-3"><a href="#" class="fdTableSortTrigger" title="Sort on “P/VP”">P/VP</a></th>\n<th style="-moz-user-select: none;" class="sortable-numeric fd-column-4"><a href="#" class="fdTableSortTrigger" title="Sort on “PSR”">PSR</a></th>\n<th style="-moz-user-select: none;" class="sortable-numeric fd-column-5"><a href="#" class="fdTableSortTrigger
# ...

# %%
tabela = pd.read_html(str(html_tabela), thousands= ".", decimal= ",")[0]
tabela
# Out:
# C:\Users\Usuário\AppData\Local\Temp\ipykernel_11776\3863686754.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabela = pd.read_html(str(html_tabela), thousands= ".", decimal= ",")[0]
#       Papel  Cotação      P/L  P/VP    PSR Div.Yield  P/Ativo  P/Cap.Giro  \
# 0     POPR4    10.17     0.00  0.00  0.000     0,00%    0.000        0.00
# 1     PORP4     2.40     0.00  0.00  0.000     0,00%    0.000        0.00
# 2     PMET3     0.00     0.00  0.00  0.000     0,00%    0.000        0.00
# 3     CLAN3     0.00     0.00  0.00  0.000     0,00%    0.000        0.00
# 4     CSTB3   150.00     0.00  0.00  0.000     0,00%    0.000        0.00
# ..      ...      ...      ...   ...    ...       ...      ...         ...
# 981  UBBR11    14.75  1201.81  3.91  0.000     0,00%    0.000        0.00
# ...

# %%
driver.quit()

# %% [markdown]
# ## Dados de Criptomoedas
# #### Dados do CoinMarketCap

# %%
# !pip install cryptocmd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from cryptocmd import CmcScraper

# %%
scraper = CmcScraper("BTC")

dados_cripto = scraper.get_dataframe()
dados_cripto
# Out:
#            Date          Open          High           Low         Close  \
# 0    2024-04-16  63419.298488  64355.669263  61716.402329  63811.863941
# 1    2024-04-15  65739.644539  66878.646905  62332.071524  63426.210018
# 2    2024-04-14  63836.231837  65824.427083  62205.851719  65738.723887
# 3    2024-04-13  67188.376427  67931.429364  60919.106162  63821.473885
# 4    2024-04-12  70061.379601  71222.742979  65254.834345  67195.864179
# ...         ...           ...           ...           ...           ...
# 4002 2013-05-02    116.379997    125.599998     92.281898    105.209999
# 4003 2013-05-01    139.000000    139.889999    107.720001    116.989998
# 4004 2013-04-30    144.000000    146.929993    134.050003    139.000000
# 4005 2013-04-29    134.444000    147.488007    134.000000    144.539993
# 4006 2013-04-28    136.689455    143.365942    110.845593    127.954255
#
#             Volume    Market Cap                 Time Open  \
# ...

# %% [markdown]
# ## Dados do Banco Central

# %%
# !pip install python-bcb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from bcb import sgs

# %%
dados_bc = sgs.get({"DOLAR": 1})
dados_bc = sgs.get({"IPCA": 433})
dados_bc
# Out:
#             IPCA
# Date
# 1980-01-01  6.62
# 1980-02-01  4.62
# 1980-03-01  6.04
# 1980-04-01  5.29
# 1980-05-01  5.70
# ...          ...
# 2023-11-01  0.28
# 2023-12-01  0.56
# 2024-01-01  0.42
# 2024-02-01  0.83
# 2024-03-01  0.16
#
# [531 rows x 1 columns]

# %% [markdown]
# ## Dados coletados via leitura de documentos

# %%
dados_shopping = pd.read_csv("shoppings.csv")
dados_shopping
# Out:
#                             Shopping  Area por m2                    City  \
# 0              ÁGUAS CLARAS SHOPPING        12626               Brasília
# 1              ÁGUAS LINDAS SHOPPING        67788  Águas Lindas de Goiás
# 2               ALAMEDA JUIZ DE FORA        12437           Juiz de Fora
# 3                   ALAMEDA SHOPPING         4807               Brasília
# 4                  ALPHA SQUARE MALL            0                Barueri
# ..                               ...          ...                     ...
# 624             VILLAGIO MALL CENTER         5943                  Bauru
# 625             ASSIS PLAZA SHOPPING         1991                  Assis
# 626                   MEGA MODA PARK         9920                Goiânia
# 627                 RIVIERA SHOPPING        37393               Bertioga
# 628  SHOPPING CENTER PACO DO OUVIDOR         2000         Rio de Janeiro
#
#     State
# 0      DF
# 1      GO
# 2      MG
# 3      DF
# 4      SP
# ..    ...
# ...

# %%
pib_municipios = pd.read_excel("pib_municipios.xlsx")
pib_municipios
# Out:
#                             City        pib
# 0     Alta Floresta D'Oeste (RO)     734469
# 1                 Ariquemes (RO)    3209761
# 2                    Cabixi (RO)     238412
# 3                    Cacoal (RO)    2792383
# 4                Cerejeiras (RO)     743037
# ...                          ...        ...
# 5565             Vianópolis (GO)     857968
# 5566         Vicentinópolis (GO)     480173
# 5567               Vila Boa (GO)     179899
# 5568          Vila Propício (GO)     308013
# 5569               Brasília (DF)  286943782
#
# [5570 rows x 2 columns]
